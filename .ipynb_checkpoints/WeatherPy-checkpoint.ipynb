# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import time
from scipy.stats import linregress
import requests
import json
from pprint import pprint

from api_keys import weather_api_key

from citipy import citipy

# %%
# Define empty lists to hold city names and lat-lng pairs
cities = []
lat_lngs = []

# Define latitude and longitude ranges
lat_range = (-90, 90)
lng_range = (-180, 180)

# Generate random latitudes and longitudes
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)

# Get nearest city for each lat-lng pair and add to cities list
for lat, lng in zip(lats, lngs):
    city = citipy.nearest_city(lat, lng).city_name
    if city not in cities:
        cities.append(city)
        lat_lngs.append((lat, lng))

# %%
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 581

# %%
url = 'https://api.openweathermap.org/data/2.5/weather?'

city_data=[]

# Print to logger
print("Beginning Data Retrieval")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, (city, (lat, lng)) in enumerate(zip(cities, lat_lngs)):

    # Group cities in sets of 50 for logging purposes
    if i % 50 == 0:
        set_count += 1
        record_count = 1

    # Create endpoint URL with each city
    city_url = f"{url}lat={lat}&lon={lng}&appid={weather_api_key}"

    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()

        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp =city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country =city_weather['name']
        city_date = city_weather['dt']
        
        # Append the City information into city_data list
        city_data.append({"City": city, 
                        "Lat": city_lat, 
                        "Lng": city_lng, 
                        "Max Temp": city_max_temp,
                        "Humidity": city_humidity,
                        "Cloudiness": city_clouds,
                        "Wind Speed": city_wind,
                        "Country": city_country,
                        "Date": city_date})

    # If an error is experienced, skip the city
    except KeyError:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 2 | puerto ayora
# Processing Record 2 of Set 2 | kilindoni
# Processing Record 3 of Set 2 | zinjibar
# Processing Record 4 of Set 2 | almazan
# Processing Record 5 of Set 2 | invercargill
# Processing Record 6 of Set 2 | blackmans bay
# Processing Record 7 of Set 2 | nova sintra
# Processing Record 8 of Set 2 | atherton
# Processing Record 9 of Set 2 | bredasdorp
# Processing Record 10 of Set 2 | isafjordur
# Processing Record 11 of Set 2 | port lincoln
# Processing Record 12 of Set 2 | hawaiian paradise park
# Processing Record 13 of Set 2 | port-aux-francais
# Processing Record 14 of Set 2 | adamstown
# Processing Record 15 of Set 2 | puerto cabezas
# Processing Record 16 of Set 2 | fuvahmulah
# Processing Record 17 of Set 2 | reyes
# Processing Record 18 of Set 2 | mangai
# Processing Record 19 of Set 2 | abeche
# Processing Record 20 of Set 2 | grand island
# Processing Record 21 of Set 2 | nogliki
# Processing Record 22 of Set 2 | tocopilla
# Processing Record 23 of Set 2 | kargopol'
# Processing Record 24 of Set 2 | tofol
# Processing Record 25 of Set 2 | grytviken
# Processing Record 26 of Set 2 | edinburgh of the seven seas
# Processing Record 27 of Set 2 | nova vicosa
# Processing Record 28 of Set 2 | anadyr
# Processing Record 29 of Set 2 | margaret river
# Processing Record 30 of Set 2 | jamestown
# Processing Record 31 of Set 2 | qaqortoq
# Processing Record 32 of Set 2 | ishikawa
# Processing Record 33 of Set 2 | mandiana
# Processing Record 34 of Set 2 | lompoc
# Processing Record 35 of Set 2 | ilulissat
# Processing Record 36 of Set 2 | sitka
# Processing Record 37 of Set 2 | albany
# Processing Record 38 of Set 2 | sao borja
# Processing Record 39 of Set 2 | enriquillo
# Processing Record 40 of Set 2 | waitangi
# Processing Record 41 of Set 2 | ust-nera
# Processing Record 42 of Set 2 | puerto natales
# Processing Record 43 of Set 2 | rio san juan
# Processing Record 44 of Set 2 | lupane
# Processing Record 45 of Set 2 | james island
# Processing Record 46 of Set 2 | vorgashor
# Processing Record 47 of Set 2 | west island
# Processing Record 48 of Set 2 | alice springs
# Processing Record 49 of Set 2 | remire-montjoly
# Processing Record 50 of Set 2 | khorixas
# Processing Record 1 of Set 3 | constantia
# Processing Record 2 of Set 3 | parras de la fuente
# Processing Record 3 of Set 3 | roshchino
# Processing Record 4 of Set 3 | gadzhiyevo
# Processing Record 5 of Set 3 | takab
# Processing Record 6 of Set 3 | nappanee
# Processing Record 7 of Set 3 | keflavik
# Processing Record 8 of Set 3 | porvoo
# Processing Record 9 of Set 3 | inari
# Processing Record 10 of Set 3 | ancud
# Processing Record 11 of Set 3 | taiohae
# Processing Record 12 of Set 3 | krasnoshchekovo
# Processing Record 13 of Set 3 | quiberon
# Processing Record 14 of Set 3 | betafo
# Processing Record 15 of Set 3 | krasnoufimsk
# Processing Record 16 of Set 3 | kodiak
# Processing Record 17 of Set 3 | talnakh
# Processing Record 18 of Set 3 | balsas
# Processing Record 19 of Set 3 | la dorada
# Processing Record 20 of Set 3 | tsiombe
# Processing Record 21 of Set 3 | utrik
# Processing Record 22 of Set 3 | al 'alamayn
# Processing Record 23 of Set 3 | nar'yan-mar
# Processing Record 24 of Set 3 | soio
# Processing Record 25 of Set 3 | nephi
# Processing Record 26 of Set 3 | aasiaat
# Processing Record 27 of Set 3 | carauari
# Processing Record 28 of Set 3 | chenzhou
# Processing Record 29 of Set 3 | colonia
# Processing Record 30 of Set 3 | tura
# Processing Record 31 of Set 3 | katsuren-haebaru
# Processing Record 32 of Set 3 | kaoma
# Processing Record 33 of Set 3 | callao
# Processing Record 34 of Set 3 | chonchi
# Processing Record 35 of Set 3 | laguna
# Processing Record 36 of Set 3 | klyuchi
# Processing Record 37 of Set 3 | alo
# Processing Record 38 of Set 3 | dryden
# Processing Record 39 of Set 3 | daru
# Processing Record 40 of Set 3 | iqaluit
# Processing Record 41 of Set 3 | bethel
# Processing Record 42 of Set 3 | wailua homesteads
# Processing Record 43 of Set 3 | stanley
# Processing Record 44 of Set 3 | camana
# Processing Record 45 of Set 3 | ushuaia
# Processing Record 46 of Set 3 | talakan
# Processing Record 47 of Set 3 | college
# Processing Record 48 of Set 3 | port elizabeth
# Processing Record 49 of Set 3 | olonkinbyen
# Processing Record 50 of Set 3 | altay
# Processing Record 1 of Set 4 | port alfred
# Processing Record 2 of Set 4 | sao jose da coroa grande
# Processing Record 3 of Set 4 | kununurra
# Processing Record 4 of Set 4 | badger
# Processing Record 5 of Set 4 | happy valley-goose bay
# Processing Record 6 of Set 4 | crane
# Processing Record 7 of Set 4 | leitchfield
# Processing Record 8 of Set 4 | mugia
# Processing Record 9 of Set 4 | bilibino
# Processing Record 10 of Set 4 | udachny
# Processing Record 11 of Set 4 | sudak
# Processing Record 12 of Set 4 | tazovsky
# Processing Record 13 of Set 4 | yellowknife
# Processing Record 14 of Set 4 | longyearbyen
# Processing Record 15 of Set 4 | sandnessjoen
# Processing Record 16 of Set 4 | chulym
# Processing Record 17 of Set 4 | mana
# Processing Record 18 of Set 4 | namtsy
# Processing Record 19 of Set 4 | salalah
# Processing Record 20 of Set 4 | vadso
# Processing Record 21 of Set 4 | walvis bay
# Processing Record 22 of Set 4 | sisimiut
# Processing Record 23 of Set 4 | hamilton
# Processing Record 24 of Set 4 | vilhena
# Processing Record 25 of Set 4 | vila velha
# Processing Record 26 of Set 4 | vernal
# Processing Record 27 of Set 4 | punta arenas
# Processing Record 28 of Set 4 | sho'rchi
# Processing Record 29 of Set 4 | uturoa
# Processing Record 30 of Set 4 | dwarka
# Processing Record 31 of Set 4 | hilo
# Processing Record 32 of Set 4 | kill devil hills
# Processing Record 33 of Set 4 | anshun
# Processing Record 34 of Set 4 | el calafate
# Processing Record 35 of Set 4 | kwolla
# Processing Record 36 of Set 4 | mirny
# Processing Record 37 of Set 4 | port mathurin
# Processing Record 38 of Set 4 | minas de marcona
# Processing Record 39 of Set 4 | paranaiba
# Processing Record 40 of Set 4 | ambon
# Processing Record 41 of Set 4 | ribeira grande
# Processing Record 42 of Set 4 | lincoln city
# Processing Record 43 of Set 4 | aykhal
# Processing Record 44 of Set 4 | puerto san carlos
# Processing Record 45 of Set 4 | hammerfest
# Processing Record 46 of Set 4 | east london
# Processing Record 47 of Set 4 | cat ba
# Processing Record 48 of Set 4 | mili
# Processing Record 49 of Set 4 | dakhla
# Processing Record 50 of Set 4 | autazes
# Processing Record 1 of Set 5 | cabo san lucas
# Processing Record 2 of Set 5 | saint-pierre
# Processing Record 3 of Set 5 | taoudenni
# Processing Record 4 of Set 5 | hadibu
# Processing Record 5 of Set 5 | harper
# Processing Record 6 of Set 5 | rikaze
# Processing Record 7 of Set 5 | stiens
# Processing Record 8 of Set 5 | kataragama
# Processing Record 9 of Set 5 | avarua
# Processing Record 10 of Set 5 | whitehorse
# Processing Record 11 of Set 5 | haiku-pauwela
# Processing Record 12 of Set 5 | papatowai
# Processing Record 13 of Set 5 | cockburn town
# Processing Record 14 of Set 5 | atafu village
# Processing Record 15 of Set 5 | codrington
# Processing Record 16 of Set 5 | pangai
# Processing Record 17 of Set 5 | dickson
# Processing Record 18 of Set 5 | patamda
# Processing Record 19 of Set 5 | bam
# Processing Record 20 of Set 5 | kingston
# Processing Record 21 of Set 5 | igrim
# Processing Record 22 of Set 5 | mastic beach
# Processing Record 23 of Set 5 | hermanus
# Processing Record 24 of Set 5 | greymouth
# Processing Record 25 of Set 5 | vilyuchinsk
# Processing Record 26 of Set 5 | doylestown
# Processing Record 27 of Set 5 | mata-utu
# Processing Record 28 of Set 5 | oranjemund
# Processing Record 29 of Set 5 | pangody
# Processing Record 30 of Set 5 | peace river
# Processing Record 31 of Set 5 | kolonia
# Processing Record 32 of Set 5 | iskateley
# Processing Record 33 of Set 5 | lambayeque
# Processing Record 34 of Set 5 | lalin
# Processing Record 35 of Set 5 | ghat
# Processing Record 36 of Set 5 | bolszewo
# Processing Record 37 of Set 5 | kapa'a
# Processing Record 38 of Set 5 | fort bragg
# Processing Record 39 of Set 5 | arnedo
# Processing Record 40 of Set 5 | as sulayyil
# Processing Record 41 of Set 5 | howard springs
# Processing Record 42 of Set 5 | rio verde de mato grosso
# Processing Record 43 of Set 5 | puerto baquerizo moreno
# Processing Record 44 of Set 5 | banamba
# Processing Record 45 of Set 5 | ventersburg
# Processing Record 46 of Set 5 | mariental
# Processing Record 47 of Set 5 | ta`u
# Processing Record 48 of Set 5 | dudinka
# Processing Record 49 of Set 5 | weno
# Processing Record 50 of Set 5 | starokucherganovka
# Processing Record 1 of Set 6 | huarmey
# Processing Record 2 of Set 6 | black river
# Processing Record 3 of Set 6 | bei'an
# Processing Record 4 of Set 6 | matthew town
# Processing Record 5 of Set 6 | wanxian
# Processing Record 6 of Set 6 | vila franca do campo
# Processing Record 7 of Set 6 | polyarnyy
# Processing Record 8 of Set 6 | lihue
# Processing Record 9 of Set 6 | bhamo
# Processing Record 10 of Set 6 | hayma'
# Processing Record 11 of Set 6 | toga village
# Processing Record 12 of Set 6 | tyazhinskiy
# Processing Record 13 of Set 6 | anloga
# Processing Record 14 of Set 6 | choibalsan
# Processing Record 15 of Set 6 | pereslavl'-zalesskiy
# Processing Record 16 of Set 6 | at taj
# Processing Record 17 of Set 6 | impfondo
# Processing Record 18 of Set 6 | kamaishi
# Processing Record 19 of Set 6 | wilton
# Processing Record 20 of Set 6 | murrells inlet
# Processing Record 21 of Set 6 | gamba
# Processing Record 22 of Set 6 | saldanha
# Processing Record 23 of Set 6 | barakani
# Processing Record 24 of Set 6 | liman
# Processing Record 25 of Set 6 | yeraliyev
# Processing Record 26 of Set 6 | touros
# Processing Record 27 of Set 6 | afaahiti
# Processing Record 28 of Set 6 | tazacorte
# Processing Record 29 of Set 6 | thunder bay
# Processing Record 30 of Set 6 | bardai
# Processing Record 31 of Set 6 | talne
# Processing Record 32 of Set 6 | pemangkat
# Processing Record 33 of Set 6 | arteche
# Processing Record 34 of Set 6 | jwaneng
# Processing Record 35 of Set 6 | ballina
# Processing Record 36 of Set 6 | shingu
# Processing Record 37 of Set 6 | youghal
# Processing Record 38 of Set 6 | hithadhoo
# Processing Record 39 of Set 6 | xiva
# Processing Record 40 of Set 6 | posse
# Processing Record 41 of Set 6 | naze
# Processing Record 42 of Set 6 | paradip garh
# Processing Record 43 of Set 6 | kone
# Processing Record 44 of Set 6 | prado
# Processing Record 45 of Set 6 | vanimo
# Processing Record 46 of Set 6 | agios stefanos
# Processing Record 47 of Set 6 | jinchang
# Processing Record 48 of Set 6 | sao vicente
# Processing Record 49 of Set 6 | zambezi
# Processing Record 50 of Set 6 | benghazi
# Processing Record 1 of Set 7 | nadi
# Processing Record 2 of Set 7 | iquique
# Processing Record 3 of Set 7 | shahba
# Processing Record 4 of Set 7 | tiksi
# Processing Record 5 of Set 7 | acarau
# Processing Record 6 of Set 7 | geraldton
# Processing Record 7 of Set 7 | bokovskaya
# Processing Record 8 of Set 7 | st. thomas
# Processing Record 9 of Set 7 | caibarien
# Processing Record 10 of Set 7 | mar del plata
# Processing Record 11 of Set 7 | waingapu
# Processing Record 12 of Set 7 | arraial do cabo
# Processing Record 13 of Set 7 | buryn'
# Processing Record 14 of Set 7 | sorong
# Processing Record 15 of Set 7 | aktau
# Processing Record 16 of Set 7 | cargados carajos
# Processing Record 17 of Set 7 | sakakah
# Processing Record 18 of Set 7 | kolonia town
# Processing Record 19 of Set 7 | makokou
# Processing Record 20 of Set 7 | marquelia
# Processing Record 21 of Set 7 | puerto colombia
# Processing Record 22 of Set 7 | matoury
# Processing Record 23 of Set 7 | carutapera
# Processing Record 24 of Set 7 | jingmen
# Processing Record 25 of Set 7 | nemuro
# Processing Record 26 of Set 7 | guapiles
# Processing Record 27 of Set 7 | ghadamis
# Processing Record 28 of Set 7 | sinabang
# Processing Record 29 of Set 7 | musay'id
# Processing Record 30 of Set 7 | susuman
# Processing Record 31 of Set 7 | oamaru
# Processing Record 32 of Set 7 | kerikeri
# Processing Record 33 of Set 7 | new norfolk
# Processing Record 34 of Set 7 | brookings
# Processing Record 35 of Set 7 | olgii
# Processing Record 36 of Set 7 | el granada
# Processing Record 37 of Set 7 | fortuna
# Processing Record 38 of Set 7 | sibolga
# Processing Record 39 of Set 7 | stornoway
# Processing Record 40 of Set 7 | morehead city
# Processing Record 41 of Set 7 | san jose village
# Processing Record 42 of Set 7 | mitchell
# Processing Record 43 of Set 7 | nuku'alofa
# Processing Record 44 of Set 7 | douglas
# Processing Record 45 of Set 7 | brisas de zicatela
# Processing Record 46 of Set 7 | san bernardo del viento
# Processing Record 47 of Set 7 | bengkulu
# Processing Record 48 of Set 7 | faaa
# Processing Record 49 of Set 7 | angahuan
# Processing Record 50 of Set 7 | kongolo
# Processing Record 1 of Set 8 | qamdo
# Processing Record 2 of Set 8 | kalmunai
# Processing Record 3 of Set 8 | frontera
# Processing Record 4 of Set 8 | saint-georges
# Processing Record 5 of Set 8 | porbandar
# Processing Record 6 of Set 8 | san fernando
# Processing Record 7 of Set 8 | gubkinskiy
# Processing Record 8 of Set 8 | usinsk
# Processing Record 9 of Set 8 | fort st. john
# Processing Record 10 of Set 8 | svetlograd
# Processing Record 11 of Set 8 | mount darwin
# Processing Record 12 of Set 8 | kampong chhnang
# Processing Record 13 of Set 8 | rongelap
# Processing Record 14 of Set 8 | manacapuru
# Processing Record 15 of Set 8 | berwick-upon-tweed
# Processing Record 16 of Set 8 | chu
# Processing Record 17 of Set 8 | wellington
# Processing Record 18 of Set 8 | ulsteinvik
# Processing Record 19 of Set 8 | cuatro cienegas de carranza
# Processing Record 20 of Set 8 | saipan
# Processing Record 21 of Set 8 | nabire
# Processing Record 22 of Set 8 | colares
# Processing Record 23 of Set 8 | cambria
# Processing Record 24 of Set 8 | broken hill
# Processing Record 25 of Set 8 | enewetak
# Processing Record 26 of Set 8 | mutuali
# Processing Record 27 of Set 8 | saint-philippe
# Processing Record 28 of Set 8 | el haouaria
# Processing Record 29 of Set 8 | greenbrier
# Processing Record 30 of Set 8 | margate
# Processing Record 31 of Set 8 | artvin
# Processing Record 32 of Set 8 | kuala terengganu
# Processing Record 33 of Set 8 | togur
# Processing Record 34 of Set 8 | tanki leendert
# Processing Record 35 of Set 8 | beira
# Processing Record 36 of Set 8 | bride
# Processing Record 37 of Set 8 | we
# Processing Record 38 of Set 8 | dhromolaxia
# Processing Record 39 of Set 8 | san luis de la loma
# Processing Record 40 of Set 8 | leh
# Processing Record 41 of Set 8 | beyneu
# Processing Record 42 of Set 8 | ekibastuz
# Processing Record 43 of Set 8 | mukah
# Processing Record 44 of Set 8 | papao
# Processing Record 45 of Set 8 | eyl
# Processing Record 46 of Set 8 | mogocha
# Processing Record 47 of Set 8 | san patricio
# Processing Record 48 of Set 8 | samut prakan
# Processing Record 49 of Set 8 | tranovaho
# Processing Record 50 of Set 8 | eraan
# Processing Record 1 of Set 9 | pitoa
# Processing Record 2 of Set 9 | piton saint-leu
# Processing Record 3 of Set 9 | timra
# Processing Record 4 of Set 9 | angaur state
# Processing Record 5 of Set 9 | fuyang
# Processing Record 6 of Set 9 | mikashevichy
# Processing Record 7 of Set 9 | didymoteicho
# Processing Record 8 of Set 9 | vryheid
# Processing Record 9 of Set 9 | harstad
# Processing Record 10 of Set 9 | quellon
# Processing Record 11 of Set 9 | qorovulbozor
# Processing Record 12 of Set 9 | tevriz
# Processing Record 13 of Set 9 | paraiso
# Processing Record 14 of Set 9 | sanya
# Processing Record 15 of Set 9 | bikenibeu village
# Processing Record 16 of Set 9 | piacabucu
# Processing Record 17 of Set 9 | viransehir
# Processing Record 18 of Set 9 | i-n-salah
# Processing Record 19 of Set 9 | vingt cinq
# Processing Record 20 of Set 9 | sovetskaya gavan'
# Processing Record 21 of Set 9 | anta
# Processing Record 22 of Set 9 | san antonio de pale
# Processing Record 23 of Set 9 | pisco
# Processing Record 24 of Set 9 | palangkaraya
# Processing Record 25 of Set 9 | petropavlovsk-kamchatsky
# Processing Record 26 of Set 9 | egilsstadir
# Processing Record 27 of Set 9 | lazaro cardenas
# Processing Record 28 of Set 9 | fisterra
# Processing Record 29 of Set 9 | naliya
# Processing Record 30 of Set 9 | kollam
# Processing Record 31 of Set 9 | general conesa
# Processing Record 32 of Set 9 | zouerate
# Processing Record 33 of Set 9 | rabo de peixe
# Processing Record 34 of Set 9 | port saint john's
# Processing Record 35 of Set 9 | nagqu
# Processing Record 36 of Set 9 | sarreguemines
# Processing Record 37 of Set 9 | thompson
# Processing Record 38 of Set 9 | kharp
# Processing Record 39 of Set 9 | kirakira
# Processing Record 40 of Set 9 | san pedro pochutla
# Processing Record 41 of Set 9 | cururupu
# Processing Record 42 of Set 9 | plettenberg bay
# Processing Record 43 of Set 9 | kabare
# Processing Record 44 of Set 9 | miyako
# Processing Record 45 of Set 9 | berdigestyakh
# Processing Record 46 of Set 9 | weida
# Processing Record 47 of Set 9 | guerrero negro
# Processing Record 48 of Set 9 | kokopo
# Processing Record 49 of Set 9 | konarka
# Processing Record 50 of Set 9 | carnarvon
# Processing Record 1 of Set 10 | kralendijk
# Processing Record 2 of Set 10 | coquimbo
# Processing Record 3 of Set 10 | sao joao da barra
# Processing Record 4 of Set 10 | anabar
# Processing Record 5 of Set 10 | zakamensk
# Processing Record 6 of Set 10 | st. john's
# Processing Record 7 of Set 10 | bayanaul
# Processing Record 8 of Set 10 | kachug
# Processing Record 9 of Set 10 | bairnsdale
# Processing Record 10 of Set 10 | kovalam
# Processing Record 11 of Set 10 | alofi
# Processing Record 12 of Set 10 | lebu
# Processing Record 13 of Set 10 | smach mean chey
# Processing Record 14 of Set 10 | san antonio del estrecho
# Processing Record 15 of Set 10 | tahoua
# Processing Record 16 of Set 10 | romblon
# Processing Record 17 of Set 10 | itoigawa
# Processing Record 18 of Set 10 | irymple
# Processing Record 19 of Set 10 | escanaba
# Processing Record 20 of Set 10 | alexandria
# Processing Record 21 of Set 10 | longgang
# Processing Record 22 of Set 10 | mogadishu
# Processing Record 23 of Set 10 | howrah
# Processing Record 24 of Set 10 | veymandoo
# Processing Record 25 of Set 10 | puerto santa
# Processing Record 26 of Set 10 | madalena
# Processing Record 27 of Set 10 | njombe
# Processing Record 28 of Set 10 | chyorny yar
# Processing Record 29 of Set 10 | chinchilla
# Processing Record 30 of Set 10 | taltal
# Processing Record 31 of Set 10 | novoshakhtinskiy
# Processing Record 32 of Set 10 | zvishavane
# Processing Record 33 of Set 10 | bayan nur
# Processing Record 34 of Set 10 | mazara del vallo
# Processing Record 35 of Set 10 | korla
# Processing Record 36 of Set 10 | luderitz
# Processing Record 37 of Set 10 | rio grande
# Processing Record 38 of Set 10 | sechura
# Processing Record 39 of Set 10 | queenstown
# Processing Record 40 of Set 10 | parambu
# Processing Record 41 of Set 10 | saint-louis
# Processing Record 42 of Set 10 | east ballina
# Processing Record 43 of Set 10 | georgetown
# Processing Record 44 of Set 10 | newman
# Processing Record 45 of Set 10 | karratha
# Processing Record 46 of Set 10 | katsuura
# Processing Record 47 of Set 10 | port alberni
# Processing Record 48 of Set 10 | mount gambier
# Processing Record 49 of Set 10 | ourilandia do norte
# Processing Record 50 of Set 10 | newport
# Processing Record 1 of Set 11 | gua
# Processing Record 2 of Set 11 | bamboo flat
# Processing Record 3 of Set 11 | gillette
# Processing Record 4 of Set 11 | vrangel'
# Processing Record 5 of Set 11 | tamontaka
# Processing Record 6 of Set 11 | tabou
# Processing Record 7 of Set 11 | el nido
# Processing Record 8 of Set 11 | taber
# Processing Record 9 of Set 11 | taro
# Processing Record 10 of Set 11 | pitimbu
# Processing Record 11 of Set 11 | amahai
# Processing Record 12 of Set 11 | luau
# Processing Record 13 of Set 11 | tralee
# Processing Record 14 of Set 11 | genthin
# Processing Record 15 of Set 11 | chui
# Processing Record 16 of Set 11 | tuburan
# Processing Record 17 of Set 11 | north bend
# Processing Record 18 of Set 11 | palmer
# Processing Record 19 of Set 11 | yangor
# Processing Record 20 of Set 11 | dronero
# Processing Record 21 of Set 11 | fort-shevchenko
# Processing Record 22 of Set 11 | omdurman
# Processing Record 23 of Set 11 | saint-denis
# Processing Record 24 of Set 11 | prince rupert
# Processing Record 25 of Set 11 | chiili
# Processing Record 26 of Set 11 | flying fish cove
# Processing Record 27 of Set 11 | lagoa
# Processing Record 28 of Set 11 | ust-tsilma
# Processing Record 29 of Set 11 | northam
# Processing Record 30 of Set 11 | tanjung pandan
# Processing Record 31 of Set 11 | majene
# Processing Record 32 of Set 11 | richards bay
# Processing Record 33 of Set 11 | djambala
# Processing Record 34 of Set 11 | aguilar
# Processing Record 35 of Set 11 | ulan bator
# Processing Record 36 of Set 11 | pauini
# Processing Record 37 of Set 11 | gustavia
# Processing Record 38 of Set 11 | 'ohonua
# Processing Record 39 of Set 11 | camabatela
# Processing Record 40 of Set 11 | oriximina
# Processing Record 41 of Set 11 | isetskoye
# Processing Record 42 of Set 11 | paita
# Processing Record 43 of Set 11 | labytnangi
# Processing Record 44 of Set 11 | chai buri
# Processing Record 45 of Set 11 | siwa oasis
# Processing Record 46 of Set 11 | amalapuram
# Processing Record 47 of Set 11 | vilyuysk
# Processing Record 48 of Set 11 | nova olinda do norte
# Processing Record 49 of Set 11 | pacasmayo
# Processing Record 50 of Set 11 | nangomba
# Processing Record 1 of Set 12 | winnemucca
# Processing Record 2 of Set 12 | korhogo
# Processing Record 3 of Set 12 | forster
# Processing Record 4 of Set 12 | inarajan village
# Processing Record 5 of Set 12 | cumaribo
# Processing Record 6 of Set 12 | boguchany
# Processing Record 7 of Set 12 | nuuk
# Processing Record 8 of Set 12 | templeton
# Processing Record 9 of Set 12 | masaki-cho
# Processing Record 10 of Set 12 | mount isa
# Processing Record 11 of Set 12 | biloela
# Processing Record 12 of Set 12 | murray bridge
# Processing Record 13 of Set 12 | ola
# Processing Record 14 of Set 12 | aibak
# Processing Record 15 of Set 12 | sarnen
# Processing Record 16 of Set 12 | kantharalak
# Processing Record 17 of Set 12 | caleta de carquin
# Processing Record 18 of Set 12 | whakatane
# Processing Record 19 of Set 12 | vohimanitra
# Processing Record 20 of Set 12 | la'ie
# Processing Record 21 of Set 12 | khandyga
# Processing Record 22 of Set 12 | nakasongola
# Processing Record 23 of Set 12 | jagraon
# Processing Record 24 of Set 12 | al kharijah
# Processing Record 25 of Set 12 | kapuskasing
# Processing Record 26 of Set 12 | yeppoon
# Processing Record 27 of Set 12 | mersing
# Processing Record 28 of Set 12 | gisborne
# Processing Record 29 of Set 12 | nikolayevsk-on-amure
# Processing Record 30 of Set 12 | sonsorol village
# Processing Record 31 of Set 12 | manokwari
# Processing Record 32 of Set 12 | axim
# Processing Record 33 of Set 12 | uliastay
# Processing Record 34 of Set 12 | nizhniy odes
# Processing Record 35 of Set 12 | al hawatah
# Processing Record 36 of Set 12 | baixa grande
# Processing Record 37 of Set 12 | fuerte olimpo
# Processing Record 38 of Set 12 | dem'yanovo
# Processing Record 39 of Set 12 | tsuruoka
# Processing Record 40 of Set 12 | kasongo-lunda
# Processing Record 41 of Set 12 | maues
# Processing Record 42 of Set 12 | zaozersk
# Processing Record 43 of Set 12 | bahia honda
# Processing Record 44 of Set 12 | zykovo
# Processing Record 45 of Set 12 | alicante
# Processing Record 46 of Set 12 | pangkalanbuun
# Processing Record 47 of Set 12 | am djarass
# Processing Record 48 of Set 12 | ytyk-kyuyel'
# Processing Record 49 of Set 12 | sterling
# Processing Record 50 of Set 12 | belmonte
# Processing Record 1 of Set 13 | vanino
# Processing Record 2 of Set 13 | severo-yeniseyskiy
# Processing Record 3 of Set 13 | itamaraca
# Processing Record 4 of Set 13 | san jose
# Processing Record 5 of Set 13 | bajos de chila
# Processing Record 6 of Set 13 | janauba
# Processing Record 7 of Set 13 | moyuta
# Processing Record 8 of Set 13 | lerwick
# Processing Record 9 of Set 13 | tarauaca
# Processing Record 10 of Set 13 | nacozari viejo
# Processing Record 11 of Set 13 | kailua-kona
# Processing Record 12 of Set 13 | viedma
# Processing Record 13 of Set 13 | nishinoomote
# Processing Record 14 of Set 13 | urucara
# Processing Record 15 of Set 13 | chibougamau
# Processing Record 16 of Set 13 | graaff-reinet
# Processing Record 17 of Set 13 | fallon
# Processing Record 18 of Set 13 | yen bai
# Processing Record 19 of Set 13 | dubbo
# Processing Record 20 of Set 13 | kurmuk
# Processing Record 21 of Set 13 | nyuzen
# Processing Record 22 of Set 13 | yuzhno-kurilsk
# Processing Record 23 of Set 13 | cuyo
# Processing Record 24 of Set 13 | krasnyy yar
# Processing Record 25 of Set 13 | bahia de kino
# Processing Record 26 of Set 13 | guangyuan
# Processing Record 27 of Set 13 | xanxere
# Processing Record 28 of Set 13 | dalbandin
# Processing Record 29 of Set 13 | klimavichy
# Processing Record 30 of Set 13 | kattivakkam
# Processing Record 31 of Set 13 | mhamid
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df=pd.DataFrame(city_data)

# %%
city_data_df.count()
# Out:
# City          581
# Lat           581
# Lng           581
# Max Temp      581
# Humidity      581
# Cloudiness    581
# Wind Speed    581
# Country       581
# Date          581
# dtype: int64

# %%
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  puerto ayora  -8.6318  -99.6970    299.89        68          44
# 1     kilindoni  -7.2301   41.1159    300.67        74           0
# 2      zinjibar  12.4114   46.5048    302.22        79          83
# 3       almazan  41.1047   -2.8596    286.19        64          98
# 4  invercargill -69.9631  164.7245    245.54        84          10
#
#    Wind Speed                Country        Date
# 0        7.65                         1683495994
# 1        8.22                         1683495994
# 2        6.08                  Ahwar  1683495994
# 3        2.63  Rebollosa de Jadraque  1683495994
# 4        5.54                         1683495994

# %%
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %%
lat_x_axis=city_data_df['Lat']
temp_y_axis=city_data_df['Max Temp']

# %%
plt.scatter(lat_x_axis, temp_y_axis,facecolor='pink', edgecolor='black')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (C)')
plt.title('City Latitude vs. Max Temperature (2022-10-18)')
plt.grid()

plt.savefig("output_data1/Fig1.png")

plt.show()

# %%
lat_x_axis=city_data_df['Lat']
hum_y_axis=city_data_df['Humidity']

# %%
plt.scatter(lat_x_axis, hum_y_axis,facecolor='pink', edgecolor='black')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title('City Latitude vs. Humidity (2022-10-18)')
plt.grid()

plt.savefig("output_data1/Fig2.png")

plt.show()

# %%
lat_x_axis=city_data_df['Lat']
cloud_y_axis=city_data_df['Cloudiness']

# %%
plt.scatter(lat_x_axis, cloud_y_axis,facecolor='pink', edgecolor='black')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title('City Latitude vs. Cloudiness (2022-10-18)')
plt.grid()

plt.savefig("output_data1/Fig3.png")

plt.show()

# %%
lat_x_axis=city_data_df['Lat']
wind_y_axis=city_data_df['Wind Speed']

# %%
plt.scatter(lat_x_axis, wind_y_axis,facecolor='pink', edgecolor='black')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (m/s)')
plt.title('City Latitude vs. Wind Speed(2022-10-18)')
plt.grid()

plt.savefig("output_data1/Fig4.png")

plt.show()

# %%
city_data_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0               faya  18.3851   42.4509     22.06        35          21
# 1            farsund  58.0948    6.8047     13.30       100           0
# 2        new norfolk -42.7826  147.0587     11.72        58          12
# 3          jamestown  42.0970  -79.2353      5.77        77         100
# 4            lanzhou  36.0564  103.7922     14.53        48          59
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 2              1.34      AU  1666108230
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230

# %%
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]
northern_hemi_df.head()
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0             faya  18.3851   42.4509     22.06        35          21
# 1          farsund  58.0948    6.8047     13.30       100           0
# 3        jamestown  42.0970  -79.2353      5.77        77         100
# 4          lanzhou  36.0564  103.7922     14.53        48          59
# 6           albany  42.6001  -73.9662     10.36        74          29
#
#          Wind Speed Country        Date
# City_ID
# 0              2.60      SA  1666108228
# 1              7.65      NO  1666108228
# 3              9.77      US  1666107934
# 4              1.20      CN  1666108230
# 6              2.10      US  1666108231

# %%
southern_hemi_df = city_data_df[city_data_df['Lat'] <= 0]
southern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 2         new norfolk -42.7826  147.0587     11.72        58          12
# 5             ushuaia -54.8000  -68.3000      8.81        81          75
# 7           carnarvon -24.8667  113.6333     20.02        76           0
# 9        saint-pierre -21.3393   55.4781     22.82        68           0
# 10           colorado -22.8375  -51.9731     20.36        86          96
#
#          Wind Speed Country        Date
# City_ID
# 2              1.34      AU  1666108230
# 5              3.09      AR  1666108231
# 7              7.46      AU  1666108232
# 9              5.14      RE  1666108236
# 10             4.69      BR  1666107965

# %%
# Define x and y values
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")

# Annotate the line equation
plt.annotate(line_eq,(10,20),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.7161472181434118

# %%
# Define x and y values
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")

# Annotate the line equation
plt.annotate(line_eq,(10,20),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Southern Hemisphere - Max Temp vs. Latitude Linear Regression')

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
# Out:
# The r-value is: 0.4121057168607245

# %%
# Define x and y values
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df[""]

# Perform linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)

# Get regression values
regress_values = x_values * slope + intercept

# Create line equation string
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create scatter plot
plt.scatter(x_values,y_values)

# Plot regression line
plt.plot(x_values,regress_values,"r-")

# Annotate the line equation
plt.annotate(line_eq,(10,20),fontsize=15,color="red")

# Label plot
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title('Northern Hemisphere - Max Temp vs. Latitude Linear Regression')

# Print r value
print(f"The r-value is: {rvalue**2}")

# Show plot
plt.show()
